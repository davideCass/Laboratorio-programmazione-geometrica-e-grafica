# %% [markdown]
# # Workshop_05

# %%
## leggo i vertici dal file .lines e li trascrivo in un dizionario chiave = vertice, valore = indice così vengono eliminati i
## duplicati

from collections import defaultdict
from larlib import*

with open("pianta_villa_cornaro.lines") as f:
    i = 0
    V = {}
    for line in f:
        x1 = round(float(line.split(",")[0]),7)     ## scrivo la coordinata e la tronco alle prima 7 cifre dopo la virgola
        y1 = round(float(line.split(",")[1]),7) 
        x2 = round(float(line.split(",")[2]),7)
        y2 = round(float(line.split(",")[3]),7)
        V[(x1,y1)] = i       
        V[(x2,y2)] = i+1
        i = i+2

## creo un dizionario di segmenti dagli indici dei vertici in V 

with open("pianta_villa_cornaro.lines") as f:
    EV = []
    for line in f:
        x1 = round(float(line.split(",")[0]),7)
        y1 = round(float(line.split(",")[1]),7) 
        x2 = round(float(line.split(",")[2]),7)
        y2 = round(float(line.split(",")[3]),7)
        EV.append([V[(x1,y1)], V[(x2,y2)]])

# %%
V
# Out:
# {(77.871635, 252.22745): 31,
#  (77.871635, 322.863215): 30,
#  (166.01402, 252.23555): 47,
#  (166.01402, 278.061709): 46,
#  (166.60866, 296.02585): 39,
#  (166.60866, 322.901699): 38,
#  (195.015536, 252.23555): 42,
#  (195.015536, 278.061709): 44,
#  (195.02365, 90.282028): 7,
#  (195.02365, 139.210228): 6,
#  (195.02365, 139.21024): 15,
#  (195.02365, 182.62538): 23,
#  (195.02365, 182.625386): 14,
#  (195.02365, 252.22745): 55,
#  (195.02365, 252.227454): 22,
#  (195.02365, 322.86323): 54,
#  (195.023655, 252.22745): 26,
#  (195.023655, 322.863215): 28,
#  (195.062136, 296.02585): 34,
#  (195.062136, 322.901699): 36,
#  (263.59204, 322.86322): 63,
#  (263.59204, 376.270756): 62,
#  (269.105063, 90.282028): 2,
#  (269.105063, 139.210228): 4,
#  (269.105063, 139.21024): 10,
#  (269.105063, 182.625386): 12,
#  (269.105071, 182.62538): 18,
#  (269.105071, 252.227454): 20,
#  (269.10672, 90.242615): 111,
#  (269.10672, 139.208599): 110,
#  (315.62131, 252.22745): 50,
#  (315.62131, 322.86323): 52,
#  (360.76926, 251.80125): 71,
#  (360.76926, 322.664096): 70,
#  (406.69513, 90.277084): 103,
#  (406.69513, 139.215145): 102,
#  (406.7928, 90.242615): 106,
#  (406.7928, 139.208599): 108,
#  (406.92264, 183.30617): 87,
#  (406.92264, 251.674944): 86,
#  (406.94202, 139.56583): 95,
#  (406.94202, 183.303493): 94,
#  (412.78857, 322.86322): 58,
#  (412.78857, 376.270756): 60,
#  (478.23065, 295.77228): 127,
#  (478.23065, 322.19932): 126,
#  (478.244854, 139.56583): 90,
#  (478.244854, 183.303493): 92,
#  (478.24582, 251.80125): 119,
#  (478.24582, 277.670505): 118,
#  (478.24582, 322.664096): 68,
#  (478.25912, 251.68633): 79,
#  (478.25912, 322.67085): 78,
#  (478.260781, 90.277084): 98,
#  (478.260781, 139.215145): 100,
#  (478.264223, 183.30617): 82,
#  (478.264223, 251.674944): 84,
#  (507.843563, 295.77228): 122,
#  (507.843563, 322.19932): 124,
#  (508.175603, 251.80125): 114,
#  (508.175603, 277.670505): 116,
#  (598.16111, 251.68633): 74,
#  (598.16111, 322.67085): 76}

# %%
EV
# Out:
# [[7, 2],
#  [2, 4],
#  [4, 6],
#  [6, 7],
#  [15, 10],
#  [10, 12],
#  [12, 14],
#  [14, 15],
#  [23, 18],
#  [18, 20],
#  [20, 22],
#  [22, 23],
#  [31, 26],
#  [26, 28],
#  [28, 30],
#  [30, 31],
#  [39, 34],
#  [34, 36],
#  [36, 38],
#  [38, 39],
#  [47, 42],
#  [42, 44],
#  [44, 46],
#  [46, 47],
#  [55, 50],
#  [50, 52],
#  [52, 54],
#  [54, 55],
#  [63, 58],
#  [58, 60],
#  [60, 62],
#  [62, 63],
#  [71, 119],
#  [119, 68],
#  [68, 70],
#  [70, 71],
#  [79, 74],
#  [74, 76],
#  [76, 78],
#  [78, 79],
#  [87, 82],
#  [82, 84],
#  [84, 86],
#  [86, 87],
#  [95, 90],
#  [90, 92],
#  [92, 94],
#  [94, 95],
#  [103, 98],
#  [98, 100],
#  [100, 102],
#  [102, 103],
#  [111, 106],
#  [106, 108],
#  [108, 110],
#  [110, 111],
#  [119, 114],
#  [114, 116],
#  [116, 118],
#  [118, 119],
#  [127, 122],
#  [122, 124],
#  [124, 126],
#  [126, 127]]
